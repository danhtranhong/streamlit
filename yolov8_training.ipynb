# %%
import torch
print(torch.__version__)
print(torch.cuda.get_device_name(0))
# Out:
# 2.3.0+cu121
# NVIDIA GeForce RTX 3050 Laptop GPU

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import yaml

data = {
    #'train': '/content/gdrive/MyDrive/yolov8/trainwithaugmentation', # path to training images
    #'val': '/content/gdrive/MyDrive/yolov8/val', #path to validation images
    'train': 'D:/Data_Analytics/streamlit/waste-detection/images_train',# path to training images
    'val': 'D:/Data_Analytics/streamlit/waste-detection/images_val', #path to validation images
    'nc': 4, # number of classes
    'names': ['organic','landfill','plastic','refundable'] #class names
}

# %%
# create yaml file
with open("dataset.yaml" , "w") as f:
   yaml.dump(data,f,default_flow_style = False)

# %%
#!cp /mnt/d/Data_Analytics/streamlit/dataset.yaml /mnt/d/Data_Analytics/streamlit/waste-detection/dataset.yaml

# !copy "D:\\Data_Analytics\\streamlit\\dataset.yaml" "D:\\Data_Analytics\\streamlit\\waste-detection\\dataset.yaml"
# Out:
#         1 file(s) copied.

# %%
import ultralytics
a = ultralytics.checks()
print(a)
# Out:
# Ultralytics YOLOv8.2.2  Python-3.11.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Setup complete  (20 CPUs, 31.7 GB RAM, 268.9/322.3 GB disk)
# None

# %% [markdown]
# # Train model

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=D:\\Data_Analytics\\streamlit\\waste-detection\\dataset.yaml imgsz=640 batch=8 epochs=10 patience=5 project=D:\\Data_Analytics\\streamlit\\waste-detection\\training_results name=train_4batch_10epochs
# Out:
# Ultralytics YOLOv8.2.2 ðŸš€ Python-3.11.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %% [markdown]
# # Testing

# %%
# !yolo task=detect mode=predict model=D:\\Data_Analytics\\streamlit\\waste-detection\\training_results\\train_4batch_10epochs\\weights\\best.pt conf=0.70 source=D:\\Data_Analytics\\streamlit\\waste-detection\\images_test save=True
# Out:
# Ultralytics YOLOv8.2.2 ðŸš€ Python-3.11.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/7 D:\Data_Analytics\streamlit\waste-detection\images_test\001.jpg: 640x480 (no detections), 78.9ms
# image 2/7 D:\Data_Analytics\streamlit\waste-detection\images_test\002.jpg: 640x480 (no detections), 6.5ms
# image 3/7 D:\Data_Analytics\streamlit\waste-detection\images_test\003.jpg: 640x480 (no detections), 9.5ms
# image 4/7 D:\Data_Analytics\streamlit\waste-detection\images_test\347.jpg: 640x480 (no detections), 0.0ms
# image 5/7 D:\Data_Analytics\streamlit\waste-detection\images_test\348.jpg: 640x480 (no detections), 6.3ms
# image 6/7 D:\Data_Analytics\streamlit\waste-detection\images_test\349.jpg: 640x480 (no detections), 6.0ms
# image 7/7 D:\Data_Analytics\streamlit\waste-detection\images_test\351.jpg: 640x480 (no detections), 6.0ms
# ...

# %%
from IPython.display import Image
#Image(filename='runs/detect/predict/348.jpg')

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=D:\\Data_Analytics\\streamlit\\waste-detection\\dataset.yaml imgsz=640 batch=12 epochs=20 patience=5 project=D:\\Data_Analytics\\streamlit\\waste-detection\\training_results name=train_12batch_20epochs
# Out:
# train: Scanning D:\Data_Analytics\streamlit\waste-detection\images_train.cache... 23 images, 0 backgrounds, 0 corrupt: 100%|##########| 23/23 [00:00<?, ?it/s]
# train: Scanning D:\Data_Analytics\streamlit\waste-detection\images_train.cache... 23 images, 0 backgrounds, 0 corrupt: 100%|##########| 23/23 [00:00<?, ?it/s]
#
# val: Scanning D:\Data_Analytics\streamlit\waste-detection\images_val...:   0%|          | 0/3 [00:00<?, ?it/s]
# val: Scanning D:\Data_Analytics\streamlit\waste-detection\images_val... 3 images, 0 backgrounds, 0 corrupt: 100%|##########| 3/3 [00:00<00:00, 147.49it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#        1/20      1.64G      1.431      3.803      1.552        108        640:   0%|          | 0/2 [00:08<?, ?it/s]
#        1/20      1.64G      1.431      3.803      1.552        108        640:  50%|#####     | 1/2 [00:08<00:08,  8.41s/it]
# ...

# %%
# !yolo train resume model=D:\Data_Analytics\streamlit\waste-detection\training_results\train_12batch_20epochs\\weights\\last.pt

#!yoLO train resume model=/mnt/d/Data_Analytics/streamlit/waste-detection/training_results/train_12batch_20epochs/weights/last.pt
# Out:
# Ultralytics YOLOv8.2.2 ðŸš€ Python-3.11.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
# !yolo task=detect mode=predict model=D:\\Data_Analytics\\streamlit\\waste-detection\\training_results\\train_12batch_20epochs\\weights\\best.pt conf=0.01 source=D:\\Data_Analytics\\streamlit\\waste-detection\\images_test save=True
# Out:
# Ultralytics YOLOv8.2.2 ðŸš€ Python-3.11.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/7 D:\Data_Analytics\streamlit\waste-detection\images_test\001.jpg: 640x480 (no detections), 80.6ms
# image 2/7 D:\Data_Analytics\streamlit\waste-detection\images_test\002.jpg: 640x480 (no detections), 6.0ms
# image 3/7 D:\Data_Analytics\streamlit\waste-detection\images_test\003.jpg: 640x480 1 plastic, 2 refundables, 6.0ms
# image 4/7 D:\Data_Analytics\streamlit\waste-detection\images_test\347.jpg: 640x480 1 plastic, 1 refundable, 2.0ms
# image 5/7 D:\Data_Analytics\streamlit\waste-detection\images_test\348.jpg: 640x480 1 refundable, 4.5ms
# image 6/7 D:\Data_Analytics\streamlit\waste-detection\images_test\349.jpg: 640x480 1 plastic, 1 refundable, 2.3ms
# image 7/7 D:\Data_Analytics\streamlit\waste-detection\images_test\351.jpg: 640x480 1 plastic, 1 refundable, 4.5ms
# ...
